# %%
import leafmap

# %%
m = leafmap.Map()
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
m = leafmap.Map(center=(40, -100), zoom=4, height="600px")
m
# Out:
# Map(center=[40, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
m = leafmap.Map(
    center=(40, -100),
    zoom=4,
    zoom_control=False,
    draw_control=False,
    scale_control=False,
    fullscreen_control=False,
    attribution_control=False,
    toolbar_control=False,
)
m
# Out:
# Map(center=[40, -100], crs={'name': 'EPSG3857', 'custom': False}, default_style=MapStyle(), dragging_style=Map…

# %%
m = leafmap.Map(center=(40, -100), zoom=4, draw_control=False, height="500px")
url = "https://nominatim.openstreetmap.org/search?format=json&q={s}"
m.add_search_control(url=url, zoom=10, position="topleft")
m
# Out:
# Map(center=[40, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
m = leafmap.Map()
print(f"Number of layers: {len(m.layers)}")
print(f"Layer types: {[type(layer).__name__ for layer in m.layers]}")
# Out:
# Number of layers: 1
# Layer types: ['TileLayer']

# %%
if len(m.layers) > 1: # keeps at least one layer
    m.remove_layer(m.layers[-1])

# %%
m.clear_controls()
m.clear_layers()
m
# Out:
# Map(center=[20, 0], crs={'name': 'EPSG3857', 'custom': False}, default_style=MapStyle(), dragging_style=MapSty…

# %%
m = leafmap.Map()
m.add_basemap("OpenTopoMap")
# m.add_basemap_gui() if you want to add the GUI and choose many
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
m = leafmap.Map()
m.add_tile_layer(
    url="https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}",
    name="Google Satellite",
    attribution="Google",
)
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
m = leafmap.Map(center=[33.4484,-112.0740], zoom=10)
url = "https://imagery.nationalmap.gov/arcgis/services/USGSNAIPPlus/ImageServer/WMSServer?"
m.add_wms_layer(
    url=url,
    layers="USGSNAIPPlus:FalseColorComposite",
    name="NAIP False Color Composite",
    attribution="USGS",
    format="image/png",
    shown=True
)
m.add_tile_layer(
    url="https://mt1.google.com/vt/lyrs=h&x={x}&y={y}&z={z}",
    name="Google Labels and Roads",
    attribution="Google",
)
m
# Out:
# Map(center=[33.4484, -112.074], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %%
m = leafmap.Map(center=[33.4484,-112.0740], zoom=10)
m.add_basemap("Esri.WorldImagery")
url = "https://www.mrlc.gov/geoserver/mrlc_display/NLCD_2021_Land_Cover_L48/wms?"
m.add_wms_layer(
    url=url,
    layers="NLCD_2021_Land_Cover_L48",
    name="NLCD 2021 Land Cover",
    attribution="MRLC",
    format="image/png",
    shown=True
)
m.add_legend(title="NLCD 2021 Land Cover Type", builtin_legend="NLCD", position="bottomleft")
m
# Out:
# Map(center=[33.4484, -112.074], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %%
m = leafmap.Map(center=[33.4484, -112.0740], zoom=12)
#Syntax: [latitude, longitude]
locations = [
    [33.4216, -111.9388], # Coor Hall
    [33.4453, -112.0667], # Chase Field
    [33.4352, -112.0060], # Phoenix Sky Harbor Airport
    [33.5154, -111.9610] # Camelback Mountain Summit
]
m.add_markers(locations, draggable=True)
m
# Out:
# Map(center=[33.4484, -112.074], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %%
m = leafmap.Map()
url = "https://github.com/opengeos/datasets/releases/download/world/world_cities.csv"
m.add_marker_cluster(url, x="longitude", y="latitude", layer_name="World Cities")
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
m = leafmap.Map(center=[40, -100], zoom=4)
cities = "https://github.com/opengeos/datasets/releases/download/us/cities.csv"
regions = "https://github.com/opengeos/datasets/releases/download/us/us_regions.geojson"
m.add_geojson(regions, layer_name="US Regions")
m.add_points_from_xy(
    cities,
    x="longitude",
    y="latitude",
    color_column="region",
    icon_names=["gear","map","leaf","globe"],
    spin=True,
    add_legend=True
)
m
# Out:
# Map(center=[40, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
import geopandas as gpd

data = "https://github.com/opengeos/datasets/releases/download/vector/cables.geojson"
gdf = gpd.read_file(data)
gdf.head()
# Out:
#                                       id  \
# 0  taiwan-penghu-kinmen-matsu-no-3-tpkm3
# 1                       unitirreno-cable
# 2        kochi-lakshadweep-islands-cable
# 3                                 sagres
# 4                     continente-madeira
#
#                                       name    color  \
# 0  Taiwan Penghu Kinmen Matsu No.3 (TPKM3)  #4dbd9a
# 1                         Unitirreno Cable  #939597
# 2          Kochi-Lakshadweep Islands Cable  #939597
# 3                                   Sagres  #4ab970
# 4                       Continente-Madeira  #37b98e
#
#                                 feature_id  \
# 0  taiwan-penghu-kinmen-matsu-no-3-tpkm3-0
# 1                       unitirreno-cable-0
# 2        kochi-lakshadweep-islands-cable-0
# 3                                 sagres-0
# 4                     continente-madeira-0
#
#                                             geometry
# 0  MULTILINESTRING ((119.93948 26.15145, 120.2624...
# 1  MULTILINESTRING ((10.91257 41.06934, 11.70007 ...
# 2  MULTILINESTRING ((73.64411 10.06982, 73.91252 ...
# 3  MULTILINESTRING ((-9.10275 38.44308, -8.99992 ...
# 4  MULTILINESTRING ((-9.33156 38.69016, -10.79992...

# %%
m = leafmap.Map(center=[20,0],zoom=2)
m.add_basemap("CartoDB.DarkMatter")
data = "https://github.com/opengeos/datasets/releases/download/vector/cables.geojson"
callback = lambda feat: {"color": feat["properties"]["color"], "weight": 2}
m.add_vector(data, layer_name="Cable Lines", info_mode="on_hover", style_callback=callback)
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
url = "https://gis.m.asu.edu/server/rest/services/Campus/CampusBuilding/MapServer/0/query?where=1%3D1&outFields=*&f=geojson"
gdf = leafmap.read_vector(url)
m = leafmap.Map(center=[33.4215, -111.9388], zoom=15)
m.add_basemap("Esri.WorldImagery")
style = {"color": "#8C1D40", "fullColor": "#FFC627", "fillOpacity": 0.4, "weight": 2}
m.add_gdf(gdf, style=style, layer_name="ASU Buildings")
m
# Out:
# Map(center=[33.4215, -111.9388], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', '…

# %%
m = leafmap.Map()
data = "https://raw.githubusercontent.com/opengeos/leafmap/master/docs/data/countries.geojson"
m.add_data(
    data, column="POP_EST", scheme="Quantiles", cmap="Blues", legend_title="Population"
)
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
leafmap.maxar_collections()
# Out:
# ['BayofBengal-Cyclone-Mocha-May-23',
#  'Belize-Wildfires-June24',
#  'Brazil-Flooding-May24',
#  'Cyclone-Chido-Dec15',
#  'Cyclone-Ditwah-Sri-Lanka-Nov-2025',
#  'Cyclone-Senyar-Indonesia-Nov-2025',
#  'Cyclone-Senyar-Thailand-Nov-2025',
#  'Earthquake-Myanmar-March-2025',
#  'Emilia-Romagna-Italy-flooding-may23',
#  'Floods-Spain-Oct24',
#  'Gambia-flooding-8-11-2022',
#  'Hurricane-Fiona-9-19-2022',
#  'Hurricane-Ian-9-26-2022',
#  'Hurricane-Idalia-Florida-Aug23',
#  'Hurricane-Maria-PuertoRico-Oct-2017',
#  'Hurricane-Melissa-Oct-2025',
#  'HurricaneHelene-Oct24',
#  'HurricaneMilton-Oct24',
#  'Iceland-Volcano_Eruption-Dec-2023',
#  'India-Floods-Oct-2023',
#  'Indonesia-Earthquake22',
#  'Japan-Earthquake-Jan-2024',
#  'Kahramanmaras-turkey-earthquake-23',
#  'Kalehe-DRC-Flooding-5-8-23',
#  'Kenya-Flooding-May24',
#  'Libya-Floods-Sept-2023',
#  'Marshall-Fire-21-Update',
#  'Maui-Hawaii-fires-Aug-23',
#  'McDougallCreekWildfire-BC-Canada-Aug-23',
#  'Morocco-Earthquake-Sept-2023',
#  'Morocco-Flooding-Dec-2025',
#  'NWT-Canada-Aug-23',
#  'Nepal-Earthquake-Apr-2015',
#  'Nepal-Earthquake-Nov-2023',
#  'Nepal-Floods-Sept-2024',
#  'New-Zealand-Flooding23',
#  'Nigeria-Flooding-May-2025',
#  'Nigeria-Floods-Sept-2024',
#  'PNG-Landslide-June24',
#  'SmokeHouseCreek-Wildfires-Texas-Mar24',
#  'Sudan-flooding-8-22-2022',
#  'Texas-Flooding-July-2025',
#  'Typhoon-Kalmaegi-Nov-2025',
#  'Vanuatu-Earthquake-Dec17',
#  'WildFires-LosAngeles-Jan-2025',
#  'afghanistan-earthquake22',
#  'cyclone-emnati22',
#  'ghana-explosion22',
#  'kentucky-flooding-7-29-2022',
#  'pakistan-flooding22',
#  'shovi-georgia-landslide-8Aug23',
#  'southafrica-flooding22',
#  'tonga-volcano21',
#  'volcano-indonesia21',
#  'yellowstone-flooding22']

# %%
collection = "Kahramanmaras-turkey-earthquake-23"
url = leafmap.maxar_collection_url(collection, dtype="geojson")
url
# Out:
# 'https://raw.githubusercontent.com/giswqs/maxar-open-data/master/datasets/Kahramanmaras-turkey-earthquake-23.geojson'

# %%
gdf = leafmap.read_vector(url)
print(f"Total number of images: {len(gdf)}")
gdf.head(100)
# Out:
# Total number of images: 2115
#                     datetime platform   gsd ard_metadata_version  \
# 0  2021-02-28 08:10:22+00:00     WV03  0.39                0.0.1
# 1  2021-02-28 08:10:22+00:00     WV03  0.39                0.0.1
# 2  2021-02-28 08:10:22+00:00     WV03  0.39                0.0.1
# 3  2021-02-28 08:10:22+00:00     WV03  0.39                0.0.1
# 4  2021-02-28 08:10:23+00:00     WV03  0.39                0.0.1
# ..                       ...      ...   ...                  ...
# 95 2022-07-20 08:39:38+00:00     WV02  0.55                0.0.1
# 96 2022-07-20 08:39:38+00:00     WV02  0.55                0.0.1
# 97 2022-07-20 08:39:38+00:00     WV02  0.55                0.0.1
# 98 2022-07-26 08:19:46+00:00     WV02  0.54                0.0.1
# 99 2022-07-26 08:19:46+00:00     WV02  0.54                0.0.1
#
#           catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth  \
# 0   1040010067C49900        37  120020230322            29.4          22.0
# 1   1040010067C49900        37  120020230323            29.3          21.3
# 2   1040010067C49900        37  120020230332            29.1          20.6
# 3   1040010067C49900        37  120020230333            29.1          20.3
# 4   1040010067C49900        37  120020232100            29.4          21.8
# ..               ...       ...           ...             ...           ...
# 95  10300100D6789800        37  031133023300            24.2         344.5
# 96  10300100D6789800        37  031133023301            24.3         343.9
# 97  10300100D6789800        37  031133023310            24.4         343.2
# 98  10300100D797E100        37  031131233232            23.2         143.9
# 99  10300100D797E100        37  031131233233            23.1         144.6
#
#     view:incidence_angle  ...              grid:code  \
# 0                   57.4  ...  MXRA-Z37-120020230322
# 1                   57.6  ...  MXRA-Z37-120020230323
# 2                   57.8  ...  MXRA-Z37-120020230332
# 3                   57.8  ...  MXRA-Z37-120020230333
# 4                   57.4  ...  MXRA-Z37-120020232100
# ..                   ...  ...                    ...
# 95                  62.6  ...  MXRA-Z37-031133023300
# 96                  62.5  ...  MXRA-Z37-031133023301
# 97                  62.4  ...  MXRA-Z37-031133023310
# 98                  63.7  ...  MXRA-Z37-031131233232
# 99                  63.9  ...  MXRA-Z37-031131233233
#
#                                             proj:bbox  tile:data_area  \
# 0   600452.7792440292,4199843.75,605156.25,4204327...            20.8
# 1    604843.75,4199843.75,610156.25,4204393.030737486            23.9
# 2   609843.75,4199843.75,615155.9736693815,4204458...            24.1
# 3   614843.75,4199843.75,615155.9736693815,4204458...             1.2
# 4    600503.194703785,4194843.75,605156.25,4200156.25            24.5
# ..                                                ...             ...
# 95  243262.48583240228,4017609.184957668,244262.16...             0.4
# 96  245691.62782046685,4017126.19149604,250156.25,...            10.3
# 97  249843.75,4018216.2791011026,251621.7053677838...             2.4
# 98  314738.45123535924,4159843.75,315156.25,416316...             1.2
# 99  314843.75,4159843.75,319758.3041869086,4163163...            15.9
#
#    tile:clouds_area tile:clouds_percent  \
# 0               0.0                   0
# 1               0.0                   0
# 2               0.0                   0
# 3               0.0                   0
# 4               0.0                   0
# ..              ...                 ...
# 95              0.0                   0
# 96              0.0                   0
# 97              0.0                   0
# 98              0.0                   0
# 99              0.0                   0
#
#                                                visual  \
# 0   https://maxar-opendata.s3.amazonaws.com/events...
# 1   https://maxar-opendata.s3.amazonaws.com/events...
# 2   https://maxar-opendata.s3.amazonaws.com/events...
# 3   https://maxar-opendata.s3.amazonaws.com/events...
# 4   https://maxar-opendata.s3.amazonaws.com/events...
# ..                                                ...
# 95  https://maxar-opendata.s3.amazonaws.com/events...
# 96  https://maxar-opendata.s3.amazonaws.com/events...
# 97  https://maxar-opendata.s3.amazonaws.com/events...
# 98  https://maxar-opendata.s3.amazonaws.com/events...
# 99  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                           ms_analytic  \
# 0   https://maxar-opendata.s3.amazonaws.com/events...
# 1   https://maxar-opendata.s3.amazonaws.com/events...
# 2   https://maxar-opendata.s3.amazonaws.com/events...
# 3   https://maxar-opendata.s3.amazonaws.com/events...
# 4   https://maxar-opendata.s3.amazonaws.com/events...
# ..                                                ...
# 95  https://maxar-opendata.s3.amazonaws.com/events...
# 96  https://maxar-opendata.s3.amazonaws.com/events...
# 97  https://maxar-opendata.s3.amazonaws.com/events...
# 98  https://maxar-opendata.s3.amazonaws.com/events...
# 99  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                          pan_analytic  \
# 0   https://maxar-opendata.s3.amazonaws.com/events...
# 1   https://maxar-opendata.s3.amazonaws.com/events...
# 2   https://maxar-opendata.s3.amazonaws.com/events...
# 3   https://maxar-opendata.s3.amazonaws.com/events...
# 4   https://maxar-opendata.s3.amazonaws.com/events...
# ..                                                ...
# 95  https://maxar-opendata.s3.amazonaws.com/events...
# 96  https://maxar-opendata.s3.amazonaws.com/events...
# 97  https://maxar-opendata.s3.amazonaws.com/events...
# 98  https://maxar-opendata.s3.amazonaws.com/events...
# 99  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                             data-mask  \
# 0   https://maxar-opendata.s3.amazonaws.com/events...
# 1   https://maxar-opendata.s3.amazonaws.com/events...
# 2   https://maxar-opendata.s3.amazonaws.com/events...
# 3   https://maxar-opendata.s3.amazonaws.com/events...
# 4   https://maxar-opendata.s3.amazonaws.com/events...
# ..                                                ...
# 95  https://maxar-opendata.s3.amazonaws.com/events...
# 96  https://maxar-opendata.s3.amazonaws.com/events...
# 97  https://maxar-opendata.s3.amazonaws.com/events...
# 98  https://maxar-opendata.s3.amazonaws.com/events...
# 99  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                              geometry
# 0   POLYGON ((40.19672 37.94010, 40.14382 37.94062...
# 1   POLYGON ((40.25361 37.93950, 40.19317 37.94013...
# 2   POLYGON ((40.25006 37.93954, 40.25075 37.98047...
# 3   POLYGON ((40.30694 37.93892, 40.30768 37.98047...
# 4   POLYGON ((40.19677 37.94291, 40.19599 37.89504...
# ..                                                ...
# 95  POLYGON ((36.14573 36.27003, 36.14350 36.27026...
# 96  POLYGON ((36.18047 36.26760, 36.16934 36.26852...
# 97  POLYGON ((36.21438 36.29397, 36.22596 36.29424...
# 98  POLYGON ((36.90702 37.56709, 36.90229 37.56701...
# 99  POLYGON ((36.90348 37.56703, 36.90264 37.59693...
#
# [100 rows x 23 columns]

# %%
m = leafmap.Map()
m.add_basemap("Esri.WorldImagery")
m.add_gdf(gdf, layer_name="Footprints", zoom_to_layer=True)
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
pre_gdf = leafmap.maxar_search(collection, end_date="2023-02-06")
print(f"Total number of pre-event images: {len(pre_gdf)}")
pre_gdf.head()
# Out:
# Total number of pre-event images: 229
#                    datetime platform   gsd ard_metadata_version  \
# 0 2021-02-28 08:10:22+00:00     WV03  0.39                0.0.1
# 1 2021-02-28 08:10:22+00:00     WV03  0.39                0.0.1
# 2 2021-02-28 08:10:22+00:00     WV03  0.39                0.0.1
# 3 2021-02-28 08:10:22+00:00     WV03  0.39                0.0.1
# 4 2021-02-28 08:10:23+00:00     WV03  0.39                0.0.1
#
#          catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth  \
# 0  1040010067C49900        37  120020230322            29.4          22.0
# 1  1040010067C49900        37  120020230323            29.3          21.3
# 2  1040010067C49900        37  120020230332            29.1          20.6
# 3  1040010067C49900        37  120020230333            29.1          20.3
# 4  1040010067C49900        37  120020232100            29.4          21.8
#
#    view:incidence_angle  ...              grid:code  \
# 0                  57.4  ...  MXRA-Z37-120020230322
# 1                  57.6  ...  MXRA-Z37-120020230323
# 2                  57.8  ...  MXRA-Z37-120020230332
# 3                  57.8  ...  MXRA-Z37-120020230333
# 4                  57.4  ...  MXRA-Z37-120020232100
#
#                                            proj:bbox  tile:data_area  \
# 0  600452.7792440292,4199843.75,605156.25,4204327...            20.8
# 1   604843.75,4199843.75,610156.25,4204393.030737486            23.9
# 2  609843.75,4199843.75,615155.9736693815,4204458...            24.1
# 3  614843.75,4199843.75,615155.9736693815,4204458...             1.2
# 4   600503.194703785,4194843.75,605156.25,4200156.25            24.5
#
#   tile:clouds_area tile:clouds_percent  \
# 0              0.0                   0
# 1              0.0                   0
# 2              0.0                   0
# 3              0.0                   0
# 4              0.0                   0
#
#                                               visual  \
# 0  https://maxar-opendata.s3.amazonaws.com/events...
# 1  https://maxar-opendata.s3.amazonaws.com/events...
# 2  https://maxar-opendata.s3.amazonaws.com/events...
# 3  https://maxar-opendata.s3.amazonaws.com/events...
# 4  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                          ms_analytic  \
# 0  https://maxar-opendata.s3.amazonaws.com/events...
# 1  https://maxar-opendata.s3.amazonaws.com/events...
# 2  https://maxar-opendata.s3.amazonaws.com/events...
# 3  https://maxar-opendata.s3.amazonaws.com/events...
# 4  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                         pan_analytic  \
# 0  https://maxar-opendata.s3.amazonaws.com/events...
# 1  https://maxar-opendata.s3.amazonaws.com/events...
# 2  https://maxar-opendata.s3.amazonaws.com/events...
# 3  https://maxar-opendata.s3.amazonaws.com/events...
# 4  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                            data-mask  \
# 0  https://maxar-opendata.s3.amazonaws.com/events...
# 1  https://maxar-opendata.s3.amazonaws.com/events...
# 2  https://maxar-opendata.s3.amazonaws.com/events...
# 3  https://maxar-opendata.s3.amazonaws.com/events...
# 4  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                             geometry
# 0  POLYGON ((40.19672 37.94010, 40.14382 37.94062...
# 1  POLYGON ((40.25361 37.93950, 40.19317 37.94013...
# 2  POLYGON ((40.25006 37.93954, 40.25075 37.98047...
# 3  POLYGON ((40.30694 37.93892, 40.30768 37.98047...
# 4  POLYGON ((40.19677 37.94291, 40.19599 37.89504...
#
# [5 rows x 23 columns]

# %%
post_gdf = leafmap.maxar_search(collection, start_date="2023-02-06")
print(f"Total number of post-event images: {len(post_gdf)}")
post_gdf.head()
# Out:
# Total number of post-event images: 1886
#                      datetime platform   gsd ard_metadata_version  \
# 229 2023-02-07 08:27:01+00:00     WV03  0.31                0.0.1
# 230 2023-02-07 08:27:01+00:00     WV03  0.31                0.0.1
# 231 2023-02-07 08:27:01+00:00     WV03  0.31                0.0.1
# 232 2023-02-07 08:27:01+00:00     WV03  0.31                0.0.1
# 233 2023-02-07 08:27:02+00:00     WV03  0.31                0.0.1
#
#            catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth  \
# 229  1040010082698700        37  031133010300             5.7         180.5
# 230  1040010082698700        37  031133010301             5.7         181.3
# 231  1040010082698700        37  031133010310             5.7         186.0
# 232  1040010082698700        37  031133010311             5.8         188.8
# 233  1040010082698700        37  031133010302             5.7         180.6
#
#      view:incidence_angle  ...              grid:code  \
# 229                  83.8  ...  MXRA-Z37-031133010300
# 230                  83.8  ...  MXRA-Z37-031133010301
# 231                  83.7  ...  MXRA-Z37-031133010310
# 232                  83.7  ...  MXRA-Z37-031133010311
# 233                  83.7  ...  MXRA-Z37-031133010302
#
#                                              proj:bbox  tile:data_area  \
# 229  284307.55615234375,4134843.75,285156.25,413773...             2.3
# 230  284843.75,4134843.75,290156.25,4137711.7919921875            14.8
# 231  289843.75,4134843.75,295156.25,4137567.7490234375            14.2
# 232  294843.75,4134843.75,297504.8828125,4137500.61...             6.9
# 233   284180.908203125,4129843.75,285156.25,4135156.25             4.8
#
#     tile:clouds_area tile:clouds_percent  \
# 229              0.0                   0
# 230              0.1                   0
# 231              0.0                   0
# 232              0.0                   0
# 233              0.0                   0
#
#                                                 visual  \
# 229  https://maxar-opendata.s3.amazonaws.com/events...
# 230  https://maxar-opendata.s3.amazonaws.com/events...
# 231  https://maxar-opendata.s3.amazonaws.com/events...
# 232  https://maxar-opendata.s3.amazonaws.com/events...
# 233  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                            ms_analytic  \
# 229  https://maxar-opendata.s3.amazonaws.com/events...
# 230  https://maxar-opendata.s3.amazonaws.com/events...
# 231  https://maxar-opendata.s3.amazonaws.com/events...
# 232  https://maxar-opendata.s3.amazonaws.com/events...
# 233  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                           pan_analytic  \
# 229  https://maxar-opendata.s3.amazonaws.com/events...
# 230  https://maxar-opendata.s3.amazonaws.com/events...
# 231  https://maxar-opendata.s3.amazonaws.com/events...
# 232  https://maxar-opendata.s3.amazonaws.com/events...
# 233  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                              data-mask  \
# 229  https://maxar-opendata.s3.amazonaws.com/events...
# 230  https://maxar-opendata.s3.amazonaws.com/events...
# 231  https://maxar-opendata.s3.amazonaws.com/events...
# 232  https://maxar-opendata.s3.amazonaws.com/events...
# 233  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                               geometry
# 229  POLYGON ((36.56529 37.36127, 36.57405 37.36116...
# 230  POLYGON ((36.57052 37.36120, 36.57135 37.33537...
# 231  POLYGON ((36.62697 37.36105, 36.62774 37.33652...
# 232  POLYGON ((36.68693 37.36163, 36.69621 37.36150...
# 233  POLYGON ((36.56530 37.33806, 36.57478 37.33826...
#
# [5 rows x 23 columns]

# %%
m = leafmap.Map()
m.add_basemap("Esri.WorldImagery")
pre_style = {"color": "red", "fillColor": "red", "opacity": 1, "fillOpacity": 0.5}
m.add_gdf(
    pre_gdf,
    layer_name="Pre-Event",
    style=pre_style,
    info_mode="on_click",
    zoom_to_layer=True
)
m.add_gdf(post_gdf, layer_name="Post-Event", info_mode="on_click", zoom_to_layer=True)
m
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
bbox = m.user_roi_bounds()
if bbox is None:
    bbox = [36.8715, 37.5497, 36.9814, 37.6019]

# %%
print(f"Bounding box: {bbox}")
# Out:
# Bounding box: [36.8715, 37.5497, 36.9814, 37.6019]

# %%
import geopandas as gpd

# union_all() was added in GeoPandas 1.0; patch for older versions
if not hasattr(gpd.GeoDataFrame, 'union_all'):
    gpd.GeoDataFrame.union_all = lambda self, **kwargs: self.geometry.unary_union

# %%
pre_event = leafmap.maxar_search(collection, bbox=bbox, end_date="2023-02-06")
pre_event
# Out:
#                      datetime platform   gsd ard_metadata_version  \
# 98  2022-07-26 08:19:46+00:00     WV02  0.54                0.0.1
# 99  2022-07-26 08:19:46+00:00     WV02  0.54                0.0.1
# 100 2022-07-26 08:19:46+00:00     WV02  0.54                0.0.1
# 101 2022-07-26 08:19:46+00:00     WV02  0.54                0.0.1
#
#            catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth  \
# 98   10300100D797E100        37  031131233232            23.2         143.9
# 99   10300100D797E100        37  031131233233            23.1         144.6
# 100  10300100D797E100        37  031133011010            23.1         143.8
# 101  10300100D797E100        37  031133011011            22.9         144.5
#
#      view:incidence_angle  ...              grid:code  \
# 98                   63.7  ...  MXRA-Z37-031131233232
# 99                   63.9  ...  MXRA-Z37-031131233233
# 100                  63.9  ...  MXRA-Z37-031133011010
# 101                  64.1  ...  MXRA-Z37-031133011011
#
#                                              proj:bbox  tile:data_area  \
# 98   314738.45123535924,4159843.75,315156.25,416316...             1.2
# 99   314843.75,4159843.75,319758.3041869086,4163163...            15.9
# 100  314714.4264589311,4158758.460866644,315156.25,...             0.5
# 101  314843.75,4158659.1890106304,319695.2811615013...             6.9
#
#     tile:clouds_area tile:clouds_percent  \
# 98               0.0                   0
# 99               0.0                   0
# 100              0.0                   0
# 101              0.0                   0
#
#                                                 visual  \
# 98   https://maxar-opendata.s3.amazonaws.com/events...
# 99   https://maxar-opendata.s3.amazonaws.com/events...
# 100  https://maxar-opendata.s3.amazonaws.com/events...
# 101  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                            ms_analytic  \
# 98   https://maxar-opendata.s3.amazonaws.com/events...
# 99   https://maxar-opendata.s3.amazonaws.com/events...
# 100  https://maxar-opendata.s3.amazonaws.com/events...
# 101  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                           pan_analytic  \
# 98   https://maxar-opendata.s3.amazonaws.com/events...
# 99   https://maxar-opendata.s3.amazonaws.com/events...
# 100  https://maxar-opendata.s3.amazonaws.com/events...
# 101  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                              data-mask  \
# 98   https://maxar-opendata.s3.amazonaws.com/events...
# 99   https://maxar-opendata.s3.amazonaws.com/events...
# 100  https://maxar-opendata.s3.amazonaws.com/events...
# 101  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                               geometry
# 98   POLYGON ((36.90702 37.56709, 36.90229 37.56701...
# 99   POLYGON ((36.90348 37.56703, 36.90264 37.59693...
# 100  POLYGON ((36.90694 37.56991, 36.90729 37.55732...
# 101  POLYGON ((36.90340 37.56984, 36.95831 37.57081...
#
# [4 rows x 23 columns]

# %%
post_event = leafmap.maxar_search(collection, bbox=bbox, start_date="2023-02-06")
post_event.head()
# Out:
#                      datetime platform   gsd ard_metadata_version  \
# 435 2023-02-08 09:02:04+00:00     WV02  0.78                0.0.1
# 436 2023-02-08 09:02:04+00:00     WV02  0.79                0.0.1
# 439 2023-02-08 09:02:04+00:00     WV02  0.79                0.0.1
# 446 2023-02-08 09:02:04+00:00     WV02  0.78                0.0.1
# 447 2023-02-08 09:02:04+00:00     WV02  0.79                0.0.1
#
#            catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth  \
# 435  10300500D9F8D200        37  031131233232            40.2         273.1
# 436  10300500D9F8D200        37  031131233233            40.4         273.1
# 439  10300500D9F8D200        37  031131233322            40.6         273.1
# 446  10300500D9F8D200        37  031133011010            40.3         273.3
# 447  10300500D9F8D200        37  031133011011            40.5         273.3
#
#      view:incidence_angle  ...              grid:code  \
# 435                  43.6  ...  MXRA-Z37-031131233232
# 436                  43.4  ...  MXRA-Z37-031131233233
# 439                  43.1  ...  MXRA-Z37-031131233322
# 446                  43.6  ...  MXRA-Z37-031133011010
# 447                  43.3  ...  MXRA-Z37-031133011011
#
#                                      proj:bbox  tile:data_area  \
# 435  309843.75,4159843.75,315156.25,4165156.25            28.2
# 436  314843.75,4159843.75,320156.25,4165156.25            28.2
# 439  319843.75,4159843.75,325156.25,4165156.25            28.2
# 446  309843.75,4154843.75,315156.25,4160156.25            28.2
# 447  314843.75,4154843.75,320156.25,4160156.25            28.2
#
#     tile:clouds_area tile:clouds_percent  \
# 435              0.0                   0
# 436              0.0                   0
# 439              0.0                   0
# 446              0.5                   1
# 447              0.1                   0
#
#                                                 visual  \
# 435  https://maxar-opendata.s3.amazonaws.com/events...
# 436  https://maxar-opendata.s3.amazonaws.com/events...
# 439  https://maxar-opendata.s3.amazonaws.com/events...
# 446  https://maxar-opendata.s3.amazonaws.com/events...
# 447  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                            ms_analytic  \
# 435  https://maxar-opendata.s3.amazonaws.com/events...
# 436  https://maxar-opendata.s3.amazonaws.com/events...
# 439  https://maxar-opendata.s3.amazonaws.com/events...
# 446  https://maxar-opendata.s3.amazonaws.com/events...
# 447  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                           pan_analytic  \
# 435  https://maxar-opendata.s3.amazonaws.com/events...
# 436  https://maxar-opendata.s3.amazonaws.com/events...
# 439  https://maxar-opendata.s3.amazonaws.com/events...
# 446  https://maxar-opendata.s3.amazonaws.com/events...
# 447  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                              data-mask  \
# 435  https://maxar-opendata.s3.amazonaws.com/events...
# 436  https://maxar-opendata.s3.amazonaws.com/events...
# 439  https://maxar-opendata.s3.amazonaws.com/events...
# 446  https://maxar-opendata.s3.amazonaws.com/events...
# 447  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                               geometry
# 435  POLYGON ((36.84552 37.61386, 36.84690 37.56601...
# 436  POLYGON ((36.90214 37.61488, 36.90348 37.56703...
# 439  POLYGON ((36.95876 37.61588, 36.96006 37.56802...
# 446  POLYGON ((36.84682 37.56883, 36.84820 37.52098...
# 447  POLYGON ((36.90340 37.56984, 36.90474 37.52199...
#
# [5 rows x 23 columns]

# %%
pre_tile = pre_event["catalog_id"].values[0]
pre_tile
# Out:
# '10300100D797E100'

# %%
post_tile=post_event["catalog_id"].values[0]
post_tile
# Out:
# '10300500D9F8D200'

# %%
pre_stac = leafmap.maxar_tile_url(collection, pre_tile, dtype="json")
post_stac = leafmap.maxar_tile_url(collection, post_tile, dtype="json")

# %%
m = leafmap.Map()
m.split_map(
    left_layer=pre_stac,
    right_layer=post_stac,
    left_label="Pre-Event",
    right_label="Post-Event",
)
m.set_center(36.9265, 37.5762, 16)
m
# Out:
# Map(center=[37.5762, 36.9265], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %%
pre_images = pre_event["visual"].tolist()
post_images = post_event["visual"].tolist()

# %%
leafmap.maxar_download(pre_images)
leafmap.maxar_download(post_images)
# Out:
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100D797E100\031131233232.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100D797E100\031131233233.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100D797E100\031133011010.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100D797E100\031133011011.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300500D9F8D200\031131233232.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300500D9F8D200\031131233233.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300500D9F8D200\031131233322.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300500D9F8D200\031133011010.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300500D9F8D200\031133011011.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300500D9F8D200\031133011100.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E19A4400\031133011010.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E19A4400\031131233232.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E19A4400\031131233233.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E19A4400\031133011011.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E291D100\031131233233.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E291D100\031131233322.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E291D100\031133011011.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E291D100\031133011100.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E2C66F00\031131233232.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E2C66F00\031131233233.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E2C66F00\031133011010.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E2C66F00\031133011011.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E3154100\031133011010.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E3154100\031133011011.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E3154100\031133011100.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E3154100\031131233232.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E3154100\031131233233.tif already exists. Skipping...
# d:\DevSource\gis322\lecture6_advancedvisualization\10300100E3154100\031131233322.tif already exists. Skipping...

# %%
import leafmap.maplibregl as leafmap

# %%
m = leafmap.Map(style="voyager", projection="globe")
m
# Out:
# Html(children=[Map(calls=[['addControl', ('NavigationControl', {'showCompass': True, 'showZoom': True, 'visual…

# %%
m = leafmap.Map(center=[11.255,43.77], zoom=13, style="positron")
m.add_control("fullscreen", position="top-right")
m.add_control("navigation", position="top-left")
m.add_draw_control(position="bottom-left")
m
# Out:
# Html(children=[Map(calls=[['addControl', ('NavigationControl', {'showCompass': True, 'showZoom': True, 'visual…

# %%
import os

# %%
m = leafmap.Map(
    center=[-122.1874314, 46.2022386], zoom=13, pitch=60, bearing=220, style="3d-hybrid"
)
m.add_layer_control(bg_layers=True)
m
# Out:
# Html(children=[Map(calls=[['addControl', ('NavigationControl', {'showCompass': True, 'showZoom': True, 'visual…

# %%
m = leafmap.Map(
    center=[-111.9400, 33.4255], zoom=16, pitch=60, bearing=45, style="basic-v2"
)
MAPTILER_KEY = os.environ["MAPTILER_KEY"]
m.add_basemap=("Esri.WorldImager")
source = {
    "url": f"https://api.maptiler.com/tiles/v3/tiles.json?key={MAPTILER_KEY}",
    "type": "vector"
}
layer = {
    "id": "3d-buildings",
    "source": "openmaptiles",
    "source-layer": "building",
    "type": "fill-extrusion",
    "min-zoom": 15,
    "paint": {
        "fill-extrusion-color": [
            "interpolate", ["linear"], ["get", "render_height"],
            0, "#F5F0E8",
            10, "#8C1D40",
            30, "#FFC627",
            60, "#FFE380"
        ],
        "fill-extrusion-height": [
            "interpolate", ["linear"], ["zoom"],
            15, 0,
            16, ["get", "render_height"]
        ],
        "fill-extrusion-base": [
            "case",
            [">=", ["get", "zoom"], 16],
            ["get", "render_min_height"],
            0,
        ],
    }
}
m.add_source("openmaptiles", source)
m.add_layer(layer)
m.add_layer_control
m
# Out:
# Html(children=[Map(calls=[['addControl', ('NavigationControl', {'showCompass': True, 'showZoom': True, 'visual…

# %%
data = "https://maplibre.org/maplibre-gl-js/docs/assets/indoor-3d-map.geojson"
gdf = leafmap.geojson_to_gdf(data)
gdf.head()
# Out:
#                                  id  level             name  height  \
# 0  06e8fa0b3f851e3ae0e1da5fc17e111e      1     Bird Exhibit       0
# 1  08a10ab2bf15c4d14669b588062f7f08      1     Bird Exhibit      40
# 2  09ead44537d94ece576c7bc001c33e53      1     East Hallway       0
# 3  12251ebf764b36cf3b8c5ad42e2deb29      1    East Entrance       0
# 4  1ce4f8c186a40b9927006644e27bfd69      1  Under the Earth       0
#
#    base_height   color                                           geometry
# 0            0  orange  POLYGON ((-87.61831 41.86628, -87.61832 41.866...
# 1            0    grey  POLYGON ((-87.61781 41.86627, -87.61781 41.866...
# 2            0  indigo  POLYGON ((-87.61670 41.86614, -87.61671 41.866...
# 3            0  violet  POLYGON ((-87.61544 41.86615, -87.61545 41.866...
# 4            0     red  POLYGON ((-87.61670 41.86582, -87.61670 41.866...

# %%
m = leafmap.Map(
    center=(-87.61694,41.86625), zoom=17, pitch=40, bearing=20, style="positron"
)
m.add_basemap("OpenStreetMap.Mapnik")
m.add_geojson(
    data,
    layer_type="fill-extrusion",
    name="floorplan",
    paint={
        "fill-extrusion-color": ["get", "color"],
        "fill-extrusion-height": ["get", "height"],
        "fill-extrusion-base": ["get", "base_height"],
        "fill-extrusion-opacity": 0.5,
    }
)
m.add_layer_control()
m
# Out:
# Html(children=[Map(calls=[['addControl', ('NavigationControl', {'showCompass': True, 'showZoom': True, 'visual…

# %%
m = leafmap.Map(center=[19.43, 49.49], zoom=3, pitch=60, style="basic")
source = {
    "type": "geojson",
    "data": "https://docs.maptiler.com/sdk-js/assets/Mean_age_of_women_at_first_marriage_in_2019.geojson",
}
m.add_source("countries", source)
layer = {
    "id": "eu-countries",
    "source": "countries",
    "type": "fill-extrusion",
    "paint": {
        "fill-extrusion-color": [
            "interpolate", ["linear"], ["get", "age"],
            23.0, "#F5F0E8",
            24.0, "#FFF5B1",
            25.0, "#FFC627",
            26.0, "#FFE380",
            27.0, "#FFFAE5",
            28.0, "#FFF5B1",
            29.0, "#FFF080",
            30.0, "#8C1D40",
        ],
        "fill-extrusion-opacity":1,
        "fill-extrusion-height": ["*", ["get", "age"], 5000],
    },
}
first_symbol_layer_id = m.find_first_symbol_layer()["id"]
m.add_layer(layer, first_symbol_layer_id)
m.add_layer_control()
m
# Out:
# Html(children=[Map(calls=[['addControl', ('NavigationControl', {'showCompass': True, 'showZoom': True, 'visual…

# %%
m = leafmap.Map(
    center=[-123.13, 49.254], zoom=11, style="dark-matter", pitch=45, bearing=0
)
url = "https://raw.githubusercontent.com/visgl/deck.gl-data/master/examples/geojson/vancouver-blocks.json"
paint_line = {
    "line-color": "white",
    "line-width": 2,
}
paint_fill = {
    "fill-extrusion-color": {
        "property": "valuePerSqm",
        "stops": [
            [0, "white"],
            [1000, "#FFF5B1"],
            [5000, "#FFF5B1"],
            [10000, "#FFF080"],
            [50000, "#8C1D40"],
        ],
    },
    "fill-extrusion-height": ["*", 10, ["sqrt", ["get", "valuePerSqm"]]],
    "fill-extrusion-opacity": 0.9,
}
m.add_geojson(url, layer_type="line", paint=paint_line, name="blocks-line")
m.add_geojson(url, layer_type="fill-extrusion", paint=paint_fill, name="blocks-fill")
m
# Out:
# Html(children=[Map(calls=[['addControl', ('NavigationControl', {'showCompass': True, 'showZoom': True, 'visual…
